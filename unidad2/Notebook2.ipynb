# %% [markdown]
# ### Unidad 2: Taller de análisis de datos textuales
#
# <h1> Notebook 2 - Topic Modeling</h1>
#
# - El modelamiento de tópicos (__Topic Modeling__) es una técnica para extraer automáticamente los tópicos ocultos de grandes volúmenes de texto. Esta técnica busca responder a la pregunta: ¿cuáles son los tópicos que se hablan en un conjunto de textos?
#
# - __Latent Dirichlet Allocation__ (LDA) es un algoritmo popular para _topic modeling_ con buenas implementaciones en el paquete Gensim de Python.
#
# - Un desafío metodológico consiste en extraer __tópicos coherentes y significativos__. Esto depende en gran medida de la calidad del preprocesamiento del texto y de la estrategia de __encontrar el número óptimo de tópicos__. Este taller propone abordar algunas buenas prácticas para resolver estos problemas.
#
# El taller tiene 2 partes, una parte guiada que ilustra cómo utilizar LDA para extraer tópicos en un dataset de discusiones de foros. La segundo parte es un trabajo práctico que apunta a reproducir una metodología de extracción de tópicos con LDA.
#
# ## Parte I - ¿Cómo aplicar LDA para extraer tópicos de un dataset de textos?

# %% [markdown]
# ### 1. Introducción
#
# Una de las principales aplicaciones del procesamiento del lenguaje natural es extraer automáticamente los temas o tópicos que la gente está discutiendo de grandes volúmenes de texto. Algunos ejemplos de textos de gran tamaño podrían ser feeds de medios sociales, reseñas de clientes de hoteles, películas, etc., feedbacks de usuarios, noticias, correos electrónicos de quejas de clientes, etc.
#
# Saber de qué habla la gente y comprender sus problemas y opiniones es muy valioso para las empresas, los administradores y las campañas políticas. Y es realmente difícil leer manualmente volúmenes tan grandes y compilar los temas.
#
# Por lo tanto, se requiere un algoritmo automatizado que pueda leer los documentos de texto y generar automáticamente los tópicos tratados.
#
# En este taller, tomaremos un ejemplo real del conjunto de datos de '20 Newsgroups' (foros de discusiones en inglés) y usaremos el algoritmos LDA para extraer los tópicos discutidos.
#
# Usaremos el paquete Latent Dirichlet Allocation (LDA) de Gensim. También extraeremos el volumen y la contribución porcentual de cada tema para tener una idea de lo importante que es un tema.

# %% [markdown]
# ## 2. Prerrequisitos y librerías necesarias - Descargar una lista de Stop-Word en inglés disponibles en el paquete NLTK
#
# Necesitaremos las palabras stop-words definidas en NLTK y también el modelo spacy para el procesamiento, en particular la lematización, del inglés.

# %%
import nltk; nltk.download('stopwords')
import nltk; nltk.download('spanish')

import spacy

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
# Out:
# [nltk_data] Downloading package stopwords to /home/fabian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading spanish: Package 'spanish' not found in
# [nltk_data]     index

# %% [markdown]
# Los paquetes principales utilizados en este taller son _re_ (expresión regular), gensim, spacy y pyLDAvis. Además de esto también usaremos matplotlib, numpy y pandas para el manejo y visualización de datos.
#
# Importamos los paquetes:

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# ### 3. ¿Qué hace LDA?
#
# El enfoque de LDA para el _Topic modeling_ es que considera cada documento como una colección de tópicos en una cierta proporción. Y cada tópico como una colección de palabras claves, de nuevo, en una cierta proporción.
#
# Una vez que uno proporciona el algoritmo con el número de temas, todo lo que hace es reorganizar la distribución de tópicos dentro de los documentos y la distribución de palabras claves dentro de los tópicos para obtener una buena composición de la distribución de tópicos y palabras clave.
#
# Cuando hablamos de __tópico__, ¿qué es realmente y cómo se representa?
#
# Un tópico no es más que un conjunto de palabras claves dominantes que son típicas de un tema dado. Con sólo mirar las palabras claves, puede identificar de qué se trata el tema.
#
# Por ejemplo, el tópico formado por las palabras: 'Sánchez', 'copa, 'ganar', 'Alexis', probablemente se refieren a un tópico que tiene que ver con el équipo chileno de fútbol.

# %% [markdown]
# ### 4. Importar el dataset
#
# Para este ejercicio utilizaremos el conjunto de datos de los 20 foros en inglés '20-Newsgroup'. Esta versión del conjunto de datos contiene unos 11.000 mensajes de grupos de noticias de 20 temas diferentes. Está disponible como newsgroups.json.
#
# Esto se importa usando pandas.read_json y el conjunto de datos resultante tiene 3 columnas como se muestra.
#
# Para reducir el tiempo de proceso, reduciremos el dataset a 1.000 mensajes.

# %%
# Import Dataset
df = pd.read_json('newsgroups.json')
print(df.target_names.unique())
df.head()
# Out:
# ['rec.autos' 'comp.sys.mac.hardware' 'rec.motorcycles' 'misc.forsale'
#  'comp.os.ms-windows.misc' 'alt.atheism' 'comp.graphics'
#  'rec.sport.baseball' 'rec.sport.hockey' 'sci.electronics' 'sci.space'
#  'talk.politics.misc' 'sci.med' 'talk.politics.mideast'
#  'soc.religion.christian' 'comp.windows.x' 'comp.sys.ibm.pc.hardware'
#  'talk.politics.guns' 'talk.religion.misc' 'sci.crypt']
#                                                 content  target  \
# 0     From: lerxst@wam.umd.edu (where's my thing)\nS...       7
# 1     From: guykuo@carson.u.washington.edu (Guy Kuo)...       4
# 10    From: irwin@cmptrc.lonestar.org (Irwin Arnstei...       8
# 100   From: tchen@magnus.acs.ohio-state.edu (Tsung-K...       6
# 1000  From: dabl2@nlm.nih.gov (Don A.B. Lindbergh)\n...       2
#
#                  target_names
# 0                   rec.autos
# 1       comp.sys.mac.hardware
# 10            rec.motorcycles
# 100              misc.forsale
# 1000  comp.os.ms-windows.misc

# %%
df=df.head(1000)

# %% [markdown]
# ### 5. Preparar las palabras Stop-Words y filtrar emails
#
# Ya hemos descargado las palabras clave. Importémoslos y hagámoslos disponibles en la variable stop_words.
#
# Como pueden ver, en el dataset hay muchos correos electrónicos, líneas nuevas y espacios adicionales que distraen bastante. Deshagámonos de ellos usando expresiones regulares y stop-words específicos.

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
# Convert to list
data = df.content.values.tolist()

# Remove Emails
data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]

# Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

pprint(data[:1])
# Out:
# ['From: (wheres my thing) Subject: WHAT car is this!? Nntp-Posting-Host: '
#  'rac3.wam.umd.edu Organization: University of Maryland, College Park Lines: '
#  '15 I was wondering if anyone out there could enlighten me on this car I saw '
#  'the other day. It was a 2-door sports car, looked to be from the late 60s/ '
#  'early 70s. It was called a Bricklin. The doors were really small. In '
#  'addition, the front bumper was separate from the rest of the body. This is '
#  'all I know. If anyone can tellme a model name, engine specs, years of '
#  'production, where this car is made, history, or whatever info you have on '
#  'this funky looking car, please e-mail. Thanks, - IL ---- brought to you by '
#  'your neighborhood Lerxst ---- ']

# %% [markdown]
# Después de eliminar los correos electrónicos y los espacios adicionales, el texto sigue pareciendo desordenado. No está listo para que el LDA lo consuma. Necesitamos tokenizar y lematizar cada frase.
#
# ### 6. Tokenizar en palabras y limpieza
#
# Vamos a convertir cada frase en una lista de palabras, eliminando los signos de puntuación y los caracteres innecesarios por completo.
#
# El <code>simple_preprocess()</code> de Gensim es comodo para esto.

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# [['from', 'wheres', 'my', 'thing', 'subject', 'what', 'car', 'is', 'this', 'nntp', 'posting', 'host', 'rac', 'wam', 'umd', 'edu', 'organization', 'university', 'of', 'maryland', 'college', 'park', 'lines', 'was', 'wondering', 'if', 'anyone', 'out', 'there', 'could', 'enlighten', 'me', 'on', 'this', 'car', 'saw', 'the', 'other', 'day', 'it', 'was', 'door', 'sports', 'car', 'looked', 'to', 'be', 'from', 'the', 'late', 'early', 'it', 'was', 'called', 'bricklin', 'the', 'doors', 'were', 'really', 'small', 'in', 'addition', 'the', 'front', 'bumper', 'was', 'separate', 'from', 'the', 'rest', 'of', 'the', 'body', 'this', 'is', 'all', 'know', 'if', 'anyone', 'can', 'tellme', 'model', 'name', 'engine', 'specs', 'years', 'of', 'production', 'where', 'this', 'car', 'is', 'made', 'history', 'or', 'whatever', 'info', 'you', 'have', 'on', 'this', 'funky', 'looking', 'car', 'please', 'mail', 'thanks', 'il', 'brought', 'to', 'you', 'by', 'your', 'neighborhood', 'lerxst']]

# %% [markdown]
# ### 7. Creación de modelos Bigram y Trigram
#
# Los bigramas son dos palabras que aparecen frecuentemente juntas en el documento. Los trigramas son 3 palabras que ocurren con frecuencia.
#
# Algunos ejemplos en nuestro ejemplo son: 'front_bumper', 'oil_leak', 'maryland_college_park' etc.
#
# Gensim puede construir e implementar los bigrams, trigramas, cuadrantes y más. Los dos argumentos importantes para las Frases son min_count y threshold. Cuanto más altos sean los valores de estos parámetros, más difícil será que las palabras se combinen con bigrams.

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['from', 'wheres', 'my', 'thing', 'subject', 'what', 'car', 'is', 'this', 'nntp_posting_host', 'rac', 'wam_umd_edu', 'organization', 'university', 'of', 'maryland_college_park', 'lines', 'was', 'wondering', 'if', 'anyone', 'out', 'there', 'could', 'enlighten', 'me', 'on', 'this', 'car', 'saw', 'the', 'other', 'day', 'it', 'was', 'door', 'sports', 'car', 'looked', 'to', 'be', 'from', 'the', 'late', 'early', 'it', 'was', 'called', 'bricklin', 'the', 'doors', 'were', 'really', 'small', 'in', 'addition', 'the', 'front', 'bumper', 'was', 'separate', 'from', 'the', 'rest', 'of', 'the', 'body', 'this', 'is', 'all', 'know', 'if', 'anyone', 'can', 'tellme', 'model', 'name', 'engine', 'specs', 'years', 'of', 'production', 'where', 'this', 'car', 'is', 'made', 'history', 'or', 'whatever', 'info', 'you', 'have', 'on', 'this', 'funky', 'looking', 'car', 'please', 'mail', 'thanks', 'il', 'brought', 'to', 'you', 'by', 'your', 'neighborhood', 'lerxst']

# %% [markdown]
# ### 9. Eliminar Stop-words, generar bigrams y lemmatizar
#
# El modelo bigrams está listo. Vamos a definir las funciones para eliminar los stop-words, hacer bigrams y lemmatización y llamarlas secuencialmente.

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

#def make_trigrams(texts):
#    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %% [markdown]
# Llamamos a la funciones en el orden:

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
#data_words_bigrams = make_bigrams(data_words_nostops)

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_nostops, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# [['where', 's', 'thing', 'car', 'nntp', 'post', 'host', 'rac', 'wam', 'umd', 'organization', 'university', 'maryland', 'college', 'park', 'line', 'wonder', 'anyone', 'could', 'enlighten', 'car', 'see', 'day', 'door', 'sport', 'car', 'look', 'late', 'early', 'call', 'bricklin', 'door', 'really', 'small', 'addition', 'front', 'bumper', 'separate', 'rest', 'body', 'know', 'anyone', 'tellme', 'model', 'name', 'engine', 'specs', 'year', 'production', 'car', 'make', 'history', 'info', 'funky', 'look', 'car', 'mail', 'thank', 'bring', 'neighborhood', 'lerxst']]

# %% [markdown]
# ## 10. Crear el diccionario y el corpus necesarios para el modelo de tópicos
#
# Las dos entradas principales al modelo de tópicos de LDA son el diccionario (id2word) y el corpus. Vamos a crearlos.

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 2), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 5), (8, 1), (9, 1), (10, 1), (11, 2), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 2), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1), (53, 1)]]

# %% [markdown]
# Gensim crea un identificador único para cada palabra del documento. El corpus producido que se muestra arriba es un mapeo de (word_id, word_frequency).
#
# Por ejemplo, (0, 1) arriba implica que la palabra id 0 ocurre una vez en el primer documento. Del mismo modo, la palabra id 1 aparece dos veces y así sucesivamente.
#
# Esto es usado como entrada por el modelo LDA.
#
# Si desea ver a qué palabra corresponde un id dado, pase el id como una llave al diccionario.

# %%
id2word[10]
# Out:
# 'day'

# %% [markdown]
# O bien, puede ver una forma legible por el ser humano del propio corpus.

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('addition', 1),
#   ('anyone', 2),
#   ('body', 1),
#   ('bricklin', 1),
#   ('bring', 1),
#   ('bumper', 1),
#   ('call', 1),
#   ('car', 5),
#   ('college', 1),
#   ('could', 1),
#   ('day', 1),
#   ('door', 2),
#   ('early', 1),
#   ('engine', 1),
#   ('enlighten', 1),
#   ('front', 1),
#   ('funky', 1),
#   ('history', 1),
#   ('host', 1),
#   ('info', 1),
#   ('know', 1),
#   ('late', 1),
#   ('lerxst', 1),
#   ('line', 1),
#   ('look', 2),
#   ('mail', 1),
#   ('make', 1),
#   ('maryland', 1),
#   ('model', 1),
#   ('name', 1),
#   ('neighborhood', 1),
#   ('nntp', 1),
#   ('organization', 1),
#   ('park', 1),
#   ('post', 1),
#   ('production', 1),
#   ('rac', 1),
#   ('really', 1),
#   ('rest', 1),
#   ('s', 1),
#   ('see', 1),
#   ('separate', 1),
#   ('small', 1),
#   ('specs', 1),
#   ('sport', 1),
#   ('tellme', 1),
#   ('thank', 1),
#   ('thing', 1),
#   ('umd', 1),
#   ('university', 1),
#   ('wam', 1),
#   ('where', 1),
#   ('wonder', 1),
#   ('year', 1)]]

# %% [markdown]
# ### 11. Construyendo el modelo de tópicos
#
# Tenemos todo lo necesario para entrenar el modelo LDA. Además del corpus y el diccionario, también debemos proporcionar el número de tópicos esperados (veremos en secciones ulteriores cómo estimar el mejor número de tópicos).
#
# _chunksize_ es el número de documentos que se utilizarán en cada chunk de entrenamiento. _update_every_ determina la frecuencia con la que se deben actualizar los parámetros del modelo y pasa es el número total de pases de entrenamiento.
#
# El proceso de entramiento del modelo de tópicos puede demorar unos minutos:

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %% [markdown]
# ## 12. Ver los tópicos del modelo LDA
#
# El modelo LDA anterior está construido con 10 tópicos diferentes donde cada tópico es una combinación de palabras claves y cada palabra clave contribuye con un cierto peso al tema.
#
# Puede ver las palabras clave para cada tema y el peso (importancia) de cada palabra clave usando lda_model.print_topics() como se muestra a continuación.

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics(num_words=20))
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.028*"apple" + 0.014*"contact" + 0.009*"laser" + 0.009*"libxmu" + '
#   '0.008*"paul" + 0.008*"sunday" + 0.008*"symbol" + 0.008*"excellent" + '
#   '0.007*"strip" + 0.007*"adobe" + 0.007*"green" + 0.007*"undefined" + '
#   '0.007*"oil" + 0.007*"tom" + 0.006*"xmu" + 0.006*"picture" + 0.006*"lunar" + '
#   '0.005*"super" + 0.005*"gary" + 0.004*"sleeve"'),
#  (1,
#   '0.012*"state" + 0.011*"right" + 0.010*"law" + 0.010*"gun" + 0.009*"church" '
#   '+ 0.009*"turkish" + 0.008*"people" + 0.008*"government" + 0.007*"maria" + '
#   '0.006*"greek" + 0.006*"american" + 0.006*"weapon" + 0.005*"shall" + '
#   '0.005*"military" + 0.005*"issue" + 0.005*"doctrine" + 0.005*"carry" + '
#   '0.005*"citizen" + 0.004*"armenia" + 0.004*"person"'),
#  (2,
#   '0.032*"israel" + 0.024*"israeli" + 0.023*"jew" + 0.015*"arab" + '
#   '0.014*"palestinian" + 0.011*"prove" + 0.009*"usr" + 0.008*"echo" + '
#   '0.007*"advertising" + 0.007*"character" + 0.006*"magazine" + 0.006*"pisga" '
#   '+ 0.006*"extra" + 0.005*"policy" + 0.005*"palestine" + 0.005*"tyre" + '
#   '0.005*"holocaust" + 0.005*"room" + 0.005*"interim" + 0.005*"talk"'),
#  (3,
#   '0.031*"scsi" + 0.015*"cd" + 0.011*"mv" + 0.010*"controller" + 0.008*"mb" + '
#   '0.007*"pc" + 0.006*"printer" + 0.005*"cds" + 0.005*"input" + '
#   '0.005*"digital" + 0.005*"tape" + 0.005*"compression" + 0.004*"resolution" + '
#   '0.004*"bj" + 0.003*"dma" + 0.003*"bus" + 0.003*"quran" + 0.003*"signal" + '
#   '0.003*"filter" + 0.003*"isa"'),
#  (4,
#   '0.024*"line" + 0.020*"organization" + 0.013*"post" + 0.012*"host" + '
#   '0.012*"nntp" + 0.011*"university" + 0.008*"get" + 0.007*"write" + '
#   '0.007*"use" + 0.007*"new" + 0.006*"article" + 0.006*"run" + 0.006*"file" + '
#   '0.006*"system" + 0.006*"distribution" + 0.006*"need" + 0.006*"thank" + '
#   '0.006*"window" + 0.006*"program" + 0.005*"problem"'),
#  (5,
#   '0.018*"not" + 0.011*"do" + 0.010*"would" + 0.010*"write" + 0.009*"say" + '
#   '0.008*"think" + 0.008*"be" + 0.007*"make" + 0.007*"article" + 0.007*"may" + '
#   '0.006*"people" + 0.006*"know" + 0.006*"god" + 0.006*"line" + 0.006*"get" + '
#   '0.005*"go" + 0.005*"organization" + 0.005*"see" + 0.005*"many" + '
#   '0.005*"thing"'),
#  (6,
#   '0.011*"astronomy" + 0.010*"dog" + 0.008*"pin" + 0.008*"devil" + '
#   '0.005*"knock" + 0.005*"racism" + 0.004*"royal" + 0.003*"meme" + '
#   '0.003*"gene" + 0.003*"dtr" + 0.001*"infect" + 0.001*"beauchaine" + '
#   '0.001*"reincarnate" + 0.001*"chase" + 0.001*"genetically" + '
#   '0.001*"molecular" + 0.001*"beaverton" + 0.001*"blew" + 0.001*"manhattan" + '
#   '0.001*"bronx"'),
#  (7,
#   '0.016*"text" + 0.012*"display" + 0.011*"jim" + 0.009*"sam" + 0.009*"van" + '
#   '0.008*"reader" + 0.008*"sony" + 0.006*"motherboard" + 0.005*"heat" + '
#   '0.005*"tel" + 0.005*"luck" + 0.005*"ignore" + 0.005*"oak" + 0.005*"min" + '
#   '0.005*"multiple" + 0.005*"dyer" + 0.005*"input" + 0.005*"packet" + '
#   '0.005*"output" + 0.005*"candida"'),
#  (8,
#   '0.013*"image" + 0.012*"plane" + 0.009*"western" + 0.009*"space" + '
#   '0.009*"copy" + 0.008*"orbit" + 0.008*"print" + 0.008*"gm" + 0.007*"nasa" + '
#   '0.006*"west" + 0.006*"datum" + 0.006*"ibm" + 0.006*"operation" + '
#   '0.005*"corporation" + 0.005*"comet" + 0.005*"cleveland" + 0.005*"ohio" + '
#   '0.005*"uucp" + 0.005*"magellan" + 0.005*"reserve"'),
#  (9,
#   '0.031*"_" + 0.017*"game" + 0.016*"team" + 0.010*"player" + 0.010*"win" + '
#   '0.008*"cx" + 0.008*"c" + 0.007*"score" + 0.007*"md" + 0.007*"ed" + '
#   '0.007*"season" + 0.007*"play" + 0.006*"lose" + 0.006*"run" + 0.006*"wing" + '
#   '0.005*"goal" + 0.005*"league" + 0.005*"baseball" + 0.005*"wide" + '
#   '0.005*"head"')]

# %% [markdown]
# __¿Cómo interpretar esto?__
#
# El tópico 7 se representa como _0.018 "game" + 0.017 "team" + 0.012 "play" + 0.012 "win" + 0.011 "year" + 0.011 "hockey" + 0.010 "player", etc.
#
# Las ponderaciones reflejan la importancia de una palabra clave para ese tema.
#
# Mirando estas palabras clave, ¿puedes adivinar cuál podría ser este tema? --> campeonato de hockey norte-americano.
#
# Del mismo modo, ¿puede repasar las palabras claves de cada tópico evaluar cuál es el tópico?

# %% [markdown]
# ## 13. Calcular las métricas de perplejidad y coherencia de los tópicos
#
# Las métricas de __perplejidad del modelo__ y la __coherencia de los tópicos__ proporcionan una medida para evaluar qué tan bueno es un modelo de tópico dado.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -9.054158788113904
#
# Coherence Score:  0.49008762129408157

# %% [markdown]
# ### 14. ¿Cómo encontrar el número óptimo de tópicos ?
#
# El enfoque clásico para encontrar el número óptimo de tópicos consiste en construir muchos modelos LDA con diferentes valores de número de tópicos (k) y elegir el que dé el valor de coherencia más alto.
#
# La elección de una "k" que marca el final de un rápido crecimiento de la coherencia temática suele ofrecer temas significativos e interpretables. Escoger un valor aún mayor puede a veces proporcionar subtópicos más granulares.
#
# Si ve que las mismas palabras clave se repiten en varios temas, es probable que sea una señal de que la 'k' es demasiado grande.
#
# Los valores de compute_coherence_values() (ver abajo) entrena múltiples modelos LDA y proporciona los modelos y sus correspondientes puntuaciones de coherencia.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=1):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=num_topics, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=3,
                                           alpha='auto',
                                           per_word_topics=True)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %% [markdown]
# Entrenar los distintos modelos puede necesitar varios minutos:

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=10, step=1)

# %%
# Show graph
limit=10; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.5379
# Num Topics = 3  has Coherence Value of 0.4949
# Num Topics = 4  has Coherence Value of 0.488
# Num Topics = 5  has Coherence Value of 0.4349
# Num Topics = 6  has Coherence Value of 0.4807
# Num Topics = 7  has Coherence Value of 0.4647
# Num Topics = 8  has Coherence Value of 0.4538
# Num Topics = 9  has Coherence Value of 0.4946

# %% [markdown]
# Si el puntaje de coherencia parece seguir aumentando, puede tener más sentido elegir el modelo que dio el puntaje más alto antes de aplanarse. Este es exactamente el caso aquí.
#
# Así que para los pasos siguientes voy a elegir el modelo con 20 temas en sí.

# %%
# Select the model and print the topics
optimal_model = model_list[3]
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.007*"not" + 0.005*"go" + 0.005*"get" + 0.005*"game" + '
#   '0.004*"organization" + 0.004*"be" + 0.004*"line" + 0.004*"last" + '
#   '0.004*"time" + 0.004*"may"'),
#  (1,
#   '0.011*"not" + 0.009*"god" + 0.009*"people" + 0.009*"say" + 0.007*"would" + '
#   '0.007*"do" + 0.006*"think" + 0.006*"believe" + 0.005*"write" + '
#   '0.005*"know"'),
#  (2,
#   '0.011*"key" + 0.008*"ripem" + 0.008*"not" + 0.005*"write" + 0.005*"israel" '
#   '+ 0.005*"public" + 0.005*"do" + 0.004*"israeli" + 0.004*"post" + '
#   '0.004*"rsa"'),
#  (3,
#   '0.027*"_" + 0.007*"md" + 0.006*"mv" + 0.006*"cx" + 0.006*"c" + 0.004*"det" '
#   '+ 0.003*"tor" + 0.002*"ed" + 0.002*"scx" + 0.002*"bj"'),
#  (4,
#   '0.016*"line" + 0.014*"organization" + 0.009*"post" + 0.008*"not" + '
#   '0.008*"write" + 0.008*"university" + 0.008*"get" + 0.007*"article" + '
#   '0.007*"host" + 0.007*"nntp"')]

# %% [markdown]
# ### 16. Encontrar el tópico dominante en cada frase o documento
#
# Una de las aplicaciones prácticas del modelo de tópicos es determinar de qué tópico trata un documento dado.
#
# Para encontrar eso, encontramos el número del tópico que tiene el porcentaje más alto de contribución en ese documento.
#
# La función format_topics_sentences() agrega esta información en una tabla presentable.

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        #row = sorted(row, key=lambda x: (x[1]), reverse=True)
        row = sorted(row[0], key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0              0.6032
# 1            1             4.0              0.9884
# 2            2             4.0              0.5486
# 3            3             4.0              0.8886
# 4            4             4.0              0.6069
# 5            5             4.0              0.9935
# 6            6             4.0              0.9741
# 7            7             4.0              0.9896
# 8            8             1.0              0.5275
# 9            9             1.0              0.5970
#
#                                             Keywords  \
# 0  not, go, get, game, organization, be, line, la...
# 1  line, organization, post, not, write, universi...
# 2  line, organization, post, not, write, universi...
# 3  line, organization, post, not, write, universi...
# 4  line, organization, post, not, write, universi...
# 5  line, organization, post, not, write, universi...
# 6  line, organization, post, not, write, universi...
# 7  line, organization, post, not, write, universi...
# 8  not, god, people, say, would, do, think, belie...
# 9  not, god, people, say, would, do, think, belie...
#
#                                                 Text
# 0  From: (wheres my thing) Subject: WHAT car is t...
# 1  From: (Guy Kuo) Subject: SI Clock Poll - Final...
# 2  From: (Irwin Arnstein) Subject: Re: Recommenda...
# 3  From: (Tsung-Kun Chen) Subject: ** Software fo...
# 4  From: (Don A.B. Lindbergh) Subject: Diamond SS...
# 5  From: (Robert Loper) Subject: Re: SHO and SC N...
# 6  From: (Kim Richard Man) Subject: SyQuest 44M c...
# 7  From: (Kirtley Wilson) Subject: Mirosoft Offic...
# 8  Subject: Re: Dont more innocents die without t...
# 9  From: (Jon Livesey) Subject: Re: Genocide is C...

# %% [markdown]
# ### 17. Encontrar el documento más representativo para cada tópico
#
# A veces las palabras claves del tópico pueden no ser suficientes para entender de qué se trata el tema. Por lo tanto, para ayudar a comprender el tópico, se puede encontrar los documentos a los que un tópico dado ha contribuido más y deducir el tema leyendo ese documento.

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet.head()
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.9117
# 1        1.0              0.9825
# 2        2.0              0.9379
# 3        3.0              0.9982
# 4        4.0              0.9935
#
#                                             Keywords  \
# 0  not, go, get, game, organization, be, line, la...
# 1  not, god, people, say, would, do, think, belie...
# 2  key, ripem, not, write, israel, public, do, is...
# 3            _, md, mv, cx, c, det, tor, ed, scx, bj
# 4  line, organization, post, not, write, universi...
#
#                                                 Text
# 0  From: (Gary L Dare) Subject: Re: ABC coverage ...
# 1  From: (David R Tucker) Subject: Re: Question: ...
# 2   zaphod.mps.ohio-state.edu!wupost!uunet!olivea...
# 3  From: (Clive Mitchell) Subject: Dataproducts L...
# 4  From: (Robert Loper) Subject: Re: SHO and SC N...

# %% [markdown]
# ### 18. Distribución de tópicos en el dataset
#
# Finalmente, queremos entender el volumen y la distribución de los tópicos para juzgar la amplitud de la discusión. La siguiente tabla expone esa información.

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics
# Out:
#      Dominant_Topic                                     Topic_Keywords  \
# 0               0.0  not, go, get, game, organization, be, line, la...
# 1               4.0  line, organization, post, not, write, universi...
# 2               4.0  line, organization, post, not, write, universi...
# 3               4.0  line, organization, post, not, write, universi...
# 4               4.0  line, organization, post, not, write, universi...
# 5               4.0  line, organization, post, not, write, universi...
# 6               4.0  line, organization, post, not, write, universi...
# 7               4.0  line, organization, post, not, write, universi...
# 8               1.0  not, god, people, say, would, do, think, belie...
# 9               1.0  not, god, people, say, would, do, think, belie...
# 10              4.0  line, organization, post, not, write, universi...
# 11              0.0  not, go, get, game, organization, be, line, la...
# 12              4.0  line, organization, post, not, write, universi...
# 13              0.0  not, go, get, game, organization, be, line, la...
# 14              0.0  not, go, get, game, organization, be, line, la...
# 15              0.0  not, go, get, game, organization, be, line, la...
# 16              4.0  line, organization, post, not, write, universi...
# 17              1.0  not, god, people, say, would, do, think, belie...
# 18              4.0  line, organization, post, not, write, universi...
# 19              4.0  line, organization, post, not, write, universi...
# 20              1.0  not, god, people, say, would, do, think, belie...
# 21              4.0  line, organization, post, not, write, universi...
# 22              4.0  line, organization, post, not, write, universi...
# 23              1.0  not, god, people, say, would, do, think, belie...
# 24              0.0  not, go, get, game, organization, be, line, la...
# 25              1.0  not, god, people, say, would, do, think, belie...
# 26              1.0  not, god, people, say, would, do, think, belie...
# 27              2.0  key, ripem, not, write, israel, public, do, is...
# 28              4.0  line, organization, post, not, write, universi...
# 29              4.0  line, organization, post, not, write, universi...
# ..              ...                                                ...
# 970             1.0  not, god, people, say, would, do, think, belie...
# 971             4.0  line, organization, post, not, write, universi...
# 972             4.0  line, organization, post, not, write, universi...
# 973             2.0  key, ripem, not, write, israel, public, do, is...
# 974             4.0  line, organization, post, not, write, universi...
# 975             4.0  line, organization, post, not, write, universi...
# 976             4.0  line, organization, post, not, write, universi...
# 977             0.0  not, go, get, game, organization, be, line, la...
# 978             1.0  not, god, people, say, would, do, think, belie...
# 979             0.0  not, go, get, game, organization, be, line, la...
# 980             0.0  not, go, get, game, organization, be, line, la...
# 981             4.0  line, organization, post, not, write, universi...
# 982             1.0  not, god, people, say, would, do, think, belie...
# 983             2.0  key, ripem, not, write, israel, public, do, is...
# 984             1.0  not, god, people, say, would, do, think, belie...
# 985             4.0  line, organization, post, not, write, universi...
# 986             4.0  line, organization, post, not, write, universi...
# 987             4.0  line, organization, post, not, write, universi...
# 988             1.0  not, god, people, say, would, do, think, belie...
# 989             4.0  line, organization, post, not, write, universi...
# 990             4.0  line, organization, post, not, write, universi...
# 991             4.0  line, organization, post, not, write, universi...
# 992             4.0  line, organization, post, not, write, universi...
# 993             4.0  line, organization, post, not, write, universi...
# 994             4.0  line, organization, post, not, write, universi...
# 995             4.0  line, organization, post, not, write, universi...
# 996             4.0  line, organization, post, not, write, universi...
# 997             1.0  not, god, people, say, would, do, think, belie...
# 998             4.0  line, organization, post, not, write, universi...
# 999             0.0  not, go, get, game, organization, be, line, la...
#
#      Num_Documents  Perc_Documents
# 0            152.0           0.152
# 1            221.0           0.221
# 2             96.0           0.096
# 3             10.0           0.010
# 4            521.0           0.521
# 5              NaN             NaN
# 6              NaN             NaN
# 7              NaN             NaN
# 8              NaN             NaN
# 9              NaN             NaN
# 10             NaN             NaN
# 11             NaN             NaN
# 12             NaN             NaN
# 13             NaN             NaN
# 14             NaN             NaN
# 15             NaN             NaN
# 16             NaN             NaN
# 17             NaN             NaN
# 18             NaN             NaN
# 19             NaN             NaN
# 20             NaN             NaN
# 21             NaN             NaN
# 22             NaN             NaN
# 23             NaN             NaN
# 24             NaN             NaN
# 25             NaN             NaN
# 26             NaN             NaN
# 27             NaN             NaN
# 28             NaN             NaN
# 29             NaN             NaN
# ..             ...             ...
# 970            NaN             NaN
# 971            NaN             NaN
# 972            NaN             NaN
# 973            NaN             NaN
# 974            NaN             NaN
# 975            NaN             NaN
# 976            NaN             NaN
# 977            NaN             NaN
# 978            NaN             NaN
# 979            NaN             NaN
# 980            NaN             NaN
# 981            NaN             NaN
# 982            NaN             NaN
# 983            NaN             NaN
# 984            NaN             NaN
# 985            NaN             NaN
# 986            NaN             NaN
# 987            NaN             NaN
# 988            NaN             NaN
# 989            NaN             NaN
# 990            NaN             NaN
# 991            NaN             NaN
# 992            NaN             NaN
# 993            NaN             NaN
# 994            NaN             NaN
# 995            NaN             NaN
# 996            NaN             NaN
# 997            NaN             NaN
# 998            NaN             NaN
# 999            NaN             NaN
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## II - Trabajo práctico
#
# La carpeta Drive siguiente contiene una serie de datasets: https://drive.google.com/drive/folders/14bt3oF4tibthkxQee0-a_esveoPwrZtd?usp=sharing
#
# Cada dataset contiene noticias de prensa publicadas por medios chilenos entre Febrero 2017 y Febrero 2018. Cada dataset fue generado buscando una palabra clave específica, por ejemplo :'feminismo', 'corrupción', 'educación', 'mapuche', 'tecnología', etc.
#
# El trabajo práctico consiste en:
# - seleccionar 1 dataset. Por ejemplo: 'tecnología'
# - aplicar una metodología basada en LDA para conocer cuáles son los tópicos conversados por los medios cuándo se habla de 'tecnología'.

# %%
# Import Dataset
df = pd.read_csv("MAD_libertad1.csv",sep='|',error_bad_lines=False,header=None)

df.head()
# Out:
#                       0                  1  \
# 0  2017-05-17 12:59:27       ElPeriodista
# 1  2017-06-01 09:33:08    EstrelladeArica
# 2  2017-05-10 12:01:21             biobio
# 3  2017-03-02 19:17:05     estrellachiloe
# 4  2017-02-27 08:15:56        Cooperativa
#
#                                                    2  \
# 0   El Periodista – Locales » Corte concede liber...
# 1   Favor le costó a mujer estar 7 meses recluida...
# 2   Justicia ordena al Servel y Gendarmería estab...
# 3   Carabineros frustró robo a las oficinas de En...
# 4   [Opinión] - Claudia Honorato - Cuando la libe...
#
#                                                    3
# 0   Santiago, 17 may (Sputnik).- La justicia otor...
# 1   09:10 Fue detenida en Chacalluta con 7 kilos ...
# 2   La Corte Suprema acogió dos nuevos recursos d...
# 3   18:50 Uno de los delincuentes fue capturado e...
# 4   Dichoso es quien conoce el verdadero valor de...

# %%
df[2][2]
# Out:
# ' Justicia ordena al Servel y Gendarmería establecer mecanismos para que presos puedan votar '

# %%
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load('es_core_news_sm', disable=['parser', 'ner'])

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('spanish')

# %%
df.rename(columns={0: "fecha", 1: "fuente", 2: "titulo", 3: "noticia"}, inplace=True)

# %%
data = df.noticia.values.tolist()

# Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

pprint(data[:1])
# Out:
# [' Santiago, 17 may (Sputnik).- La justicia otorgó este miércoles el beneficio '
#  'de libertad condicional a Sergio Apablaza Rozas, que cumple su condena en el '
#  'Penal Punta Peuco, junto a otros exuniformados que cometieron crímenes de '
#  'lesa humanidad durante la dictadura de Augusto Pinochet. “La Comisión de '
#  'Libertad Condicional de la Corte de Apelaciones de Santiago concedió la '
#  'solicitud solo a un interno, de los quince condenados por diversas causas de '
#  'violaciones a los derechos humanos de Punta Peuco que la habían pedido”, '
#  'señaló el portal electrónico Emol. Esta medida se aplicó al general retirado '
#  'de Carabineros Sergio Apablaza Rozas, penado a 5 años y un día de cárcel por '
#  'su participación en la detención y desaparición del opositor al régimen '
#  'Pedro Juan Merino Molina. Apablaza ingresó a Punta Peuco, ubicado a las '
#  'afueras de Santiago, el 21 de enero de 2015, y debía permanecer en el '
#  'recinto hasta 2020. En su informe de excarcelación, se especifica que el '
#  'recluso cumplía con las condiciones para optar a la libertad condicional, '
#  'poseía buenas referencias de los guardias de prisión, además de tener '
#  'problemas de salud. La víctima de Apablaza, Merino Molina, era un joven '
#  'sastre de la ciudad sureña de Coronel, que militó en la época en las '
#  'Juventudes Comunistas de Chile, por lo que fue detenido el 14 de septiembre '
#  'de 1974 por un grupo de carabineros y militares, que lo sacaron de su casa '
#  'en plena madrugada. Luego de ser llevado a un retén, fue conducido por los '
#  'agentes del dictador a Colonia Dignidad, el cónclave manejado por colonos '
#  'alemanes que se asentaron en el sur del país e instalaron un centro '
#  'clandestino de detención y tortura, que sirvió a Pinochet. Merino Molina '
#  'estuvo casi un mes detenido en Colonia Dignidad, y su rastro se perdió en '
#  'otro recinto de torturas en Santiago. Su nombre apareció en la lista de las '
#  '119 víctimas de la Operación Colombo, montada por la dirección de '
#  'inteligencia de la dictadura en 1975, para encubrir la desaparición forzosa '
#  'de opositores, haciendo creer a la opinión pública nacional y extranjera que '
#  'estos habían fallecido en riñas internas y con fuerzas de seguridad. La '
#  'Comisión de Libertad Condicional de la Corte de Apelaciones de Santiago '
#  'acogió 457 de las 1.606 solicitudes presentadas en el primer semestre, que '
#  'equivalen al 28 por ciento de los informes revisados. Nombre (required) Mail '
#  '(will not be published) (required) Web ']

# %%
data
# Out:
# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['santiago', 'may', 'sputnik', 'la', 'justicia', 'otorgo', 'este', 'miercoles', 'el', 'beneficio', 'de', 'libertad', 'condicional', 'sergio_apablaza_rozas', 'que', 'cumple', 'su', 'condena', 'en', 'el', 'penal', 'punta_peuco', 'junto', 'otros', 'exuniformados', 'que', 'cometieron', 'crimenes', 'de', 'lesa_humanidad', 'durante', 'la', 'dictadura', 'de', 'augusto_pinochet', 'la', 'comision', 'de', 'libertad', 'condicional', 'de', 'la', 'corte', 'de', 'apelaciones', 'de', 'santiago', 'concedio', 'la', 'solicitud', 'solo', 'un', 'interno', 'de', 'los', 'quince', 'condenados', 'por', 'diversas', 'causas', 'de', 'violaciones', 'los', 'derechos_humanos', 'de', 'punta_peuco', 'que', 'la', 'habian', 'pedido', 'senalo', 'el', 'portal', 'electronico', 'emol', 'esta', 'medida', 'se', 'aplico', 'al', 'general', 'retirado', 'de', 'carabineros', 'sergio_apablaza_rozas', 'penado', 'anos', 'un', 'dia', 'de', 'carcel', 'por', 'su', 'participacion', 'en', 'la', 'detencion', 'desaparicion', 'del', 'opositor', 'al', 'regimen', 'pedro', 'juan', 'merino_molina', 'apablaza', 'ingreso', 'punta_peuco', 'ubicado', 'las', 'afueras', 'de', 'santiago', 'el', 'de', 'enero', 'de', 'debia', 'permanecer', 'en', 'el', 'recinto', 'hasta', 'en', 'su', 'informe', 'de', 'excarcelacion', 'se', 'especifica', 'que', 'el', 'recluso', 'cumplia', 'con', 'las', 'condiciones', 'para', 'optar', 'la', 'libertad', 'condicional', 'poseia', 'buenas', 'referencias', 'de', 'los', 'guardias', 'de', 'prision', 'ademas', 'de', 'tener', 'problemas', 'de', 'salud', 'la', 'victima', 'de', 'apablaza', 'merino_molina', 'era', 'un', 'joven', 'sastre', 'de', 'la', 'ciudad', 'surena', 'de', 'coronel', 'que', 'milito', 'en', 'la', 'epoca', 'en', 'las', 'juventudes', 'comunistas', 'de', 'chile', 'por', 'lo', 'que', 'fue', 'detenido', 'el', 'de', 'septiembre', 'de', 'por', 'un', 'grupo', 'de', 'carabineros', 'militares', 'que', 'lo', 'sacaron', 'de', 'su', 'casa', 'en', 'plena', 'madrugada', 'luego', 'de', 'ser', 'llevado', 'un', 'reten', 'fue', 'conducido', 'por', 'los', 'agentes', 'del', 'dictador', 'colonia_dignidad', 'el', 'conclave', 'manejado', 'por', 'colonos', 'alemanes', 'que', 'se', 'asentaron', 'en', 'el', 'sur', 'del', 'pais', 'instalaron', 'un', 'centro', 'clandestino', 'de', 'detencion', 'tortura', 'que', 'sirvio', 'pinochet', 'merino_molina', 'estuvo', 'casi', 'un', 'mes', 'detenido', 'en', 'colonia_dignidad', 'su', 'rastro', 'se', 'perdio', 'en', 'otro', 'recinto', 'de', 'torturas', 'en', 'santiago', 'su', 'nombre', 'aparecio', 'en', 'la', 'lista', 'de', 'las', 'victimas', 'de', 'la', 'operacion', 'colombo', 'montada', 'por', 'la', 'direccion', 'de', 'inteligencia', 'de', 'la', 'dictadura', 'en', 'para', 'encubrir', 'la', 'desaparicion', 'forzosa', 'de', 'opositores', 'haciendo', 'creer', 'la', 'opinion', 'publica', 'nacional', 'extranjera', 'que', 'estos', 'habian', 'fallecido', 'en', 'rinas', 'internas', 'con', 'fuerzas', 'de', 'seguridad', 'la', 'comision', 'de', 'libertad', 'condicional', 'de', 'la', 'corte', 'de', 'apelaciones', 'de', 'santiago', 'acogio', 'de', 'las', 'solicitudes_presentadas', 'en', 'el', 'primer_semestre', 'que', 'equivalen', 'al', 'por', 'ciento', 'de', 'los', 'informes', 'revisados', 'nombre_required', 'mail', 'will', 'not', 'be', 'published', 'required', 'web']

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
#data_words_bigrams = make_bigrams(data_words_nostops)

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_nostops, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# [['santiago', 'may', 'sputnik', 'justicia', 'otorgar', 'miercoles', 'beneficiar', 'libertar', 'condicional', 'sergio', 'apablaza', 'rozar', 'cumplir', 'condenar', 'penal', 'punta', 'peuco', 'juntar', 'exuniformados', 'cometer', 'crimenes', 'leso', 'humanidad', 'dictadura', 'augusto', 'pinochet', 'comision', 'libertar', 'condicional', 'cortar', 'apelación', 'santiago', 'concedio', 'solicitud', 'solo', 'internar', 'condenar', 'causar', 'violación', 'derecho', 'humano', 'punta', 'peuco', 'habian', 'pedir', 'senalo', 'portal', 'electronico', 'emol', 'medir', 'aplicar', 'general', 'retirar', 'carabinero', 'sergio', 'apablaza', 'rozar', 'penar', 'ano', 'carcel', 'participacion', 'detencion', 'desaparicion', 'opositor', 'regimen', 'pedro', 'juan', 'merino', 'molina', 'apablaza', 'ingresar', 'punta', 'peuco', 'ubicar', 'aforar', 'santiago', 'enero', 'debia', 'permanecer', 'recinto', 'informar', 'excarcelacion', 'especificar', 'recluso', 'cumplia', 'condicionar', 'optar', 'libertar', 'condicional', 'poseia', 'bueno', 'referenciar', 'guardia', 'prision', 'ademar', 'tener', 'problema', 'salud', 'victimar', 'merino', 'molina', 'joven', 'ciudad', 'surena', 'coronel', 'militar', 'epoca', 'juventud', 'comunista', 'chile', 'detener', 'septiembre', 'grupo', 'carabinero', 'militar', 'sacar', 'casar', 'pleno', 'madrugar', 'luego', 'llevar', 'retar', 'conducir', 'agente', 'dictador', 'colonia', 'dignidad', 'conclave', 'manejar', 'colono', 'alemán', 'asentar', 'sur', 'pais', 'instalar', 'centrar', 'clandestino', 'detencion', 'torturar', 'sirvio', 'pinochet', 'merino', 'molina', 'casi', 'mes', 'detener', 'colonia', 'dignidad', 'rastro', 'perdio', 'recinto', 'torturar', 'santiago', 'nombrar', 'aparecio', 'listo', 'victimar', 'operacion', 'montar', 'direccion', 'inteligencia', 'dictadura', 'encubrir', 'desaparicion', 'forzoso', 'opositor', 'creer', 'opinion', 'publicar', 'nacional', 'extranjero', 'habian', 'fallecer', 'rinas', 'interno', 'fuerza', 'seguridad', 'comision', 'libertar', 'condicional', 'cortar', 'apelación', 'santiago', 'acogio', 'solicitud', 'presentar', '\ufeff1', 'semestre', 'equivaler', 'informe', 'revisar', 'nombrar', 'required', 'will', 'published', 'required', 'web']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 3), (7, 1), (8, 2), (9, 1), (10, 1), (11, 1), (12, 1), (13, 1), (14, 2), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 2), (24, 1), (25, 1), (26, 2), (27, 1), (28, 1), (29, 1), (30, 2), (31, 4), (32, 1), (33, 1), (34, 1), (35, 2), (36, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 2), (43, 2), (44, 2), (45, 1), (46, 2), (47, 2), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 1), (65, 2), (66, 1), (67, 1), (68, 1), (69, 1), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 4), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 3), (90, 1), (91, 1), (92, 2), (93, 3), (94, 1), (95, 1), (96, 2), (97, 1), (98, 1), (99, 2), (100, 1), (101, 1), (102, 1), (103, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 3), (111, 2), (112, 1), (113, 1), (114, 1), (115, 1), (116, 1), (117, 1), (118, 1), (119, 1), (120, 3), (121, 1), (122, 2), (123, 1), (124, 1), (125, 1), (126, 2), (127, 1), (128, 1), (129, 1), (130, 1), (131, 2), (132, 1), (133, 1), (134, 5), (135, 1), (136, 1), (137, 1), (138, 1), (139, 2), (140, 1), (141, 2), (142, 1), (143, 1), (144, 1), (145, 1), (146, 1), (147, 2), (148, 1), (149, 2), (150, 1), (151, 1), (152, 1), (153, 1)]]

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('acogio', 1),
#   ('ademar', 1),
#   ('aforar', 1),
#   ('agente', 1),
#   ('alemán', 1),
#   ('ano', 1),
#   ('apablaza', 3),
#   ('aparecio', 1),
#   ('apelación', 2),
#   ('aplicar', 1),
#   ('asentar', 1),
#   ('augusto', 1),
#   ('beneficiar', 1),
#   ('bueno', 1),
#   ('carabinero', 2),
#   ('carcel', 1),
#   ('casar', 1),
#   ('casi', 1),
#   ('causar', 1),
#   ('centrar', 1),
#   ('chile', 1),
#   ('ciudad', 1),
#   ('clandestino', 1),
#   ('colonia', 2),
#   ('colono', 1),
#   ('cometer', 1),
#   ('comision', 2),
#   ('comunista', 1),
#   ('concedio', 1),
#   ('conclave', 1),
#   ('condenar', 2),
#   ('condicional', 4),
#   ('condicionar', 1),
#   ('conducir', 1),
#   ('coronel', 1),
#   ('cortar', 2),
#   ('creer', 1),
#   ('crimenes', 1),
#   ('cumplia', 1),
#   ('cumplir', 1),
#   ('debia', 1),
#   ('derecho', 1),
#   ('desaparicion', 2),
#   ('detencion', 2),
#   ('detener', 2),
#   ('dictador', 1),
#   ('dictadura', 2),
#   ('dignidad', 2),
#   ('direccion', 1),
#   ('electronico', 1),
#   ('emol', 1),
#   ('encubrir', 1),
#   ('enero', 1),
#   ('epoca', 1),
#   ('equivaler', 1),
#   ('especificar', 1),
#   ('excarcelacion', 1),
#   ('extranjero', 1),
#   ('exuniformados', 1),
#   ('fallecer', 1),
#   ('forzoso', 1),
#   ('fuerza', 1),
#   ('general', 1),
#   ('grupo', 1),
#   ('guardia', 1),
#   ('habian', 2),
#   ('humanidad', 1),
#   ('humano', 1),
#   ('informar', 1),
#   ('informe', 1),
#   ('ingresar', 1),
#   ('instalar', 1),
#   ('inteligencia', 1),
#   ('internar', 1),
#   ('interno', 1),
#   ('joven', 1),
#   ('juan', 1),
#   ('juntar', 1),
#   ('justicia', 1),
#   ('juventud', 1),
#   ('leso', 1),
#   ('libertar', 4),
#   ('listo', 1),
#   ('llevar', 1),
#   ('luego', 1),
#   ('madrugar', 1),
#   ('manejar', 1),
#   ('may', 1),
#   ('medir', 1),
#   ('merino', 3),
#   ('mes', 1),
#   ('miercoles', 1),
#   ('militar', 2),
#   ('molina', 3),
#   ('montar', 1),
#   ('nacional', 1),
#   ('nombrar', 2),
#   ('operacion', 1),
#   ('opinion', 1),
#   ('opositor', 2),
#   ('optar', 1),
#   ('otorgar', 1),
#   ('pais', 1),
#   ('participacion', 1),
#   ('pedir', 1),
#   ('pedro', 1),
#   ('penal', 1),
#   ('penar', 1),
#   ('perdio', 1),
#   ('permanecer', 1),
#   ('peuco', 3),
#   ('pinochet', 2),
#   ('pleno', 1),
#   ('portal', 1),
#   ('poseia', 1),
#   ('presentar', 1),
#   ('prision', 1),
#   ('problema', 1),
#   ('publicar', 1),
#   ('published', 1),
#   ('punta', 3),
#   ('rastro', 1),
#   ('recinto', 2),
#   ('recluso', 1),
#   ('referenciar', 1),
#   ('regimen', 1),
#   ('required', 2),
#   ('retar', 1),
#   ('retirar', 1),
#   ('revisar', 1),
#   ('rinas', 1),
#   ('rozar', 2),
#   ('sacar', 1),
#   ('salud', 1),
#   ('santiago', 5),
#   ('seguridad', 1),
#   ('semestre', 1),
#   ('senalo', 1),
#   ('septiembre', 1),
#   ('sergio', 2),
#   ('sirvio', 1),
#   ('solicitud', 2),
#   ('solo', 1),
#   ('sputnik', 1),
#   ('sur', 1),
#   ('surena', 1),
#   ('tener', 1),
#   ('torturar', 2),
#   ('ubicar', 1),
#   ('victimar', 2),
#   ('violación', 1),
#   ('web', 1),
#   ('will', 1),
#   ('\ufeff1', 1)]]

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=3, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics(num_words=20))
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.036*"newsletter" + 0.036*"ciudad" + 0.020*"elegir" + 0.019*"chile" + '
#   '0.019*"terminos" + 0.019*"valor" + 0.018*"recibir" + 0.018*"futuro" + '
#   '0.018*"emol" + 0.018*"suscribete" + 0.018*"mundo" + 0.018*"condicionar" + '
#   '0.018*"anunciar" + 0.018*"suceder" + 0.018*"querer" + 0.017*"propiedad" + '
#   '0.017*"pronto" + 0.017*"sitiar" + 0.017*"soychile" + 0.017*"correo"'),
#  (1,
#   '0.056*"bus" + 0.040*"libertar" + 0.021*"diversidad" + 0.019*"twitter" + '
#   '0.016*"com" + 0.015*"pic" + 0.013*"cooperativo" + 0.012*"movilh" + '
#   '0.011*"carabinero" + 0.009*"llegar" + 0.008*"foto" + 0.007*"odiar" + '
#   '0.007*"recorrer" + 0.007*"chile" + 0.007*"alameda" + 0.007*"bandera" + '
#   '0.007*"pasar" + 0.006*"monedar" + 0.006*"favor" + 0.006*"generar"'),
#  (2,
#   '0.025*"libertar" + 0.010*"derecho" + 0.006*"ano" + 0.006*"chile" + '
#   '0.005*"personar" + 0.005*"condenar" + 0.005*"decir" + 0.004*"mas" + '
#   '0.004*"privar" + 0.004*"pasar" + 0.003*"partir" + 0.003*"hacer" + '
#   '0.003*"cortar" + 0.003*"juez" + 0.003*"condicional" + 0.003*"mujer" + '
#   '0.003*"solo" + 0.003*"realizar" + 0.003*"estan" + 0.003*"casar"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.4167478391074155
#
# Coherence Score:  0.6546005841128757

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=10, step=1)

# %%
# Show graph
limit=10; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             4.0              0.6963
# 1            1             4.0              0.7138
# 2            2             4.0              0.7867
# 3            3             4.0              0.7633
# 4            4             4.0              0.6657
# 5            5             1.0              0.3081
# 6            6             4.0              0.6768
# 7            7             0.0              0.4490
# 8            8             4.0              0.4222
# 9            9             4.0              0.5521
#
#                                             Keywords  \
# 0  line, organization, post, not, write, universi...
# 1  line, organization, post, not, write, universi...
# 2  line, organization, post, not, write, universi...
# 3  line, organization, post, not, write, universi...
# 4  line, organization, post, not, write, universi...
# 5  not, god, people, say, would, do, think, belie...
# 6  line, organization, post, not, write, universi...
# 7  not, go, get, game, organization, be, line, la...
# 8  line, organization, post, not, write, universi...
# 9  line, organization, post, not, write, universi...
#
#                                                 Text
# 0   Santiago, 17 may (Sputnik).- La justicia otor...
# 1   09:10 Fue detenida en Chacalluta con 7 kilos ...
# 2   La Corte Suprema acogió dos nuevos recursos d...
# 3   18:50 Uno de los delincuentes fue capturado e...
# 4   Dichoso es quien conoce el verdadero valor de...
# 5   Las organizaciones feministas de la región ad...
# 6   13:04 La jueza desestimó dolo y apremios ileg...
# 7   El año que acabamos de dejar atrás tuvo la pa...
# 8   Síguenos en: En el ataque un auto quedó total...
# 9   Santiago Viernes, 24 de febrero de 2017 Actua...

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet.head()
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.6261
# 1        1.0              0.8450
# 2        2.0              0.4960
# 3        3.0              0.3930
# 4        4.0              0.8524
#
#                                             Keywords  \
# 0  not, go, get, game, organization, be, line, la...
# 1  not, god, people, say, would, do, think, belie...
# 2  key, ripem, not, write, israel, public, do, is...
# 3            _, md, mv, cx, c, det, tor, ed, scx, bj
# 4  line, organization, post, not, write, universi...
#
#                                                 Text
# 0   Síguenos en: Sergio Catrilaf. Foto: Agencia U...
# 1   Nuestro ‘Cazador de Mitos’ nos habló de los h...
# 2   Detenida terminó la actriz Naya Rivera, recon...
# 3   El influyente semanario alemán Der Spiegel pu...
# 4   11:35 La placa estaba pintada con lapiz y peg...
